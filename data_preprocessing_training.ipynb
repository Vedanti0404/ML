# %%
# preprocessing includes collection,cleaning,transforming,splitting
#training includes model selection, ml,testing,accuracy
#remodeling for better result

# %%
#step 1: importing libararies
import pandas as pd
import numpy as np
import sklearn
print("Imported!")
# Out:
# Imported!

# %%
#collection of data --> using pandas

file=pd.read_csv("/content/seeds_dataset (2).csv")

file.head(20)
# Out:
#      Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0   15.26      14.84       0.8710             5.763            3.312
# 1   14.88      14.57       0.8811               NaN            3.333
# 2   14.29      14.09       0.9050             5.291            3.337
# 3   13.84      13.94       0.8955             5.324              NaN
# 4     NaN        NaN       0.9034             5.658            3.562
# 5   14.38      14.21       0.8951             5.386            3.312
# 6     NaN      14.49          NaN             5.563            3.259
# 7   14.11      14.10       0.8911             5.420            3.302
# 8   16.63      15.46       0.8747             6.053            3.465
# 9   16.44        NaN       0.8880             5.884            3.505
# 10    NaN      14.85       0.8696               NaN            3.242
# 11  14.03      14.16       0.8796             5.438            3.201
# 12  13.89      14.02       0.8880             5.439            3.199
# 13  13.78      14.06       0.8759             5.479            3.156
# 14  13.74      14.05       0.8744             5.482              NaN
# 15  14.59      14.28       0.8993               NaN            3.333
# 16  13.99      13.83          NaN             5.119            3.383
# 17  15.69      14.75       0.9058             5.527            3.514
# 18  14.70      14.21       0.9153             5.205            3.466
# 19  12.72        NaN       0.8686             5.226            3.049
#
#     Asymmetry coefficient  Length of kernel groove Unnamed: 7 Unnamed: 8
# 0                   2.221                    5.220        NaN        NaN
# 1                   1.018                    4.956        NaN        NaN
# 2                   2.699                    4.825        NaN        NaN
# 3                   2.259                    4.805        NaN        NaN
# 4                     NaN                    5.175        NaN        NaN
# 5                   2.462                    4.956        NaN        NaN
# 6                   3.586                    5.219        NaN        NaN
# 7                   2.700                      NaN        NaN        NaN
# 8                     NaN                    5.877        NaN        NaN
# 9                   1.969                    5.533        NaN        NaN
# 10                  4.543                    5.314        NaN        NaN
# 11                  1.717                    5.001        NaN        NaN
# 12                  3.986                    4.738        NaN        NaN
# 13                  3.136                    4.872        NaN        NaN
# 14                  2.932                    4.825        NaN        NaN
# 15                  4.185                    4.781        NaN        NaN
# 16                  5.234                    4.781        NaN        NaN
# 17                  1.599                    5.046        NaN        NaN
# 18                  1.767                    4.649        NaN        NaN
# 19                  4.102                    4.914        NaN        NaN

# %%
#finding for missing values
file.isna().sum()
# Out:
# Area                        16
# Perimeter                   14
# Compactness                 11
# Length of kernel            15
# Width of kernel             11
# Asymmetry coefficient       10
# Length of kernel groove     11
# Unnamed: 7                 208
# Unnamed: 8                 209
# dtype: int64

# %%
#look for datatypes
print(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Area                     194 non-null    float64
#  1   Perimeter                196 non-null    float64
#  2   Compactness              199 non-null    float64
#  3   Length of kernel         195 non-null    float64
#  4   Width of kernel          199 non-null    float64
#  5   Asymmetry coefficient    200 non-null    float64
#  6   Length of kernel groove  199 non-null    float64
#  7   Unnamed: 7               2 non-null      object
#  8   Unnamed: 8               1 non-null      object
# dtypes: float64(7), object(2)
# memory usage: 14.9+ KB
# None

# %%
file=file.drop("Unnamed: 7",axis=1)
file=file.drop("Unnamed: 8",axis=1)

# %%
file
# Out:
#       Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811               NaN            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324              NaN
# 4      NaN        NaN       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88          NaN             5.140              NaN
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521               NaN            2.836
# 209  12.30        NaN       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove
# 0                    2.221                    5.220
# 1                    1.018                    4.956
# 2                    2.699                    4.825
# 3                    2.259                    4.805
# 4                      NaN                    5.175
# ..                     ...                      ...
# 205                  3.631                    4.870
# 206                  4.325                    5.003
# 207                  8.315                      NaN
# 208                  3.598                    5.044
# 209                  5.637                    5.063
#
# [210 rows x 7 columns]

# %%
file
# Out:
#       Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811               NaN            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324              NaN
# 4      NaN        NaN       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88          NaN             5.140              NaN
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521               NaN            2.836
# 209  12.30        NaN       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove
# 0                    2.221                    5.220
# 1                    1.018                    4.956
# 2                    2.699                    4.825
# 3                    2.259                    4.805
# 4                      NaN                    5.175
# ..                     ...                      ...
# 205                  3.631                    4.870
# 206                  4.325                    5.003
# 207                  8.315                      NaN
# 208                  3.598                    5.044
# 209                  5.637                    5.063
#
# [210 rows x 7 columns]

# %%
print(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Area                     194 non-null    float64
#  1   Perimeter                196 non-null    float64
#  2   Compactness              199 non-null    float64
#  3   Length of kernel         195 non-null    float64
#  4   Width of kernel          199 non-null    float64
#  5   Asymmetry coefficient    200 non-null    float64
#  6   Length of kernel groove  199 non-null    float64
# dtypes: float64(7)
# memory usage: 11.6 KB
# None

# %%
#WE have missing values and all numbers in dataset
#now removing missing values
#IMPUTING-->filling missing values by number.

file=file.fillna(file.mean()) #-->filling the file data means filling NaN with the mean

# %%
file.head(20)
# Out:
#          Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0   15.260000  14.840000     0.871000          5.763000         3.312000
# 1   14.880000  14.570000     0.881100          5.630097         3.333000
# 2   14.290000  14.090000     0.905000          5.291000         3.337000
# 3   13.840000  13.940000     0.895500          5.324000         3.260231
# 4   14.888454  14.550918     0.903400          5.658000         3.562000
# 5   14.380000  14.210000     0.895100          5.386000         3.312000
# 6   14.888454  14.490000     0.870873          5.563000         3.259000
# 7   14.110000  14.100000     0.891100          5.420000         3.302000
# 8   16.630000  15.460000     0.874700          6.053000         3.465000
# 9   16.440000  14.550918     0.888000          5.884000         3.505000
# 10  14.888454  14.850000     0.869600          5.630097         3.242000
# 11  14.030000  14.160000     0.879600          5.438000         3.201000
# 12  13.890000  14.020000     0.888000          5.439000         3.199000
# 13  13.780000  14.060000     0.875900          5.479000         3.156000
# 14  13.740000  14.050000     0.874400          5.482000         3.260231
# 15  14.590000  14.280000     0.899300          5.630097         3.333000
# 16  13.990000  13.830000     0.870873          5.119000         3.383000
# 17  15.690000  14.750000     0.905800          5.527000         3.514000
# 18  14.700000  14.210000     0.915300          5.205000         3.466000
# 19  12.720000  14.550918     0.868600          5.226000         3.049000
#
#     Asymmetry coefficient  Length of kernel groove
# 0                2.221000                  5.22000
# 1                1.018000                  4.95600
# 2                2.699000                  4.82500
# 3                2.259000                  4.80500
# 4                3.712436                  5.17500
# 5                2.462000                  4.95600
# 6                3.586000                  5.21900
# 7                2.700000                  5.40595
# 8                3.712436                  5.87700
# 9                1.969000                  5.53300
# 10               4.543000                  5.31400
# 11               1.717000                  5.00100
# 12               3.986000                  4.73800
# 13               3.136000                  4.87200
# 14               2.932000                  4.82500
# 15               4.185000                  4.78100
# 16               5.234000                  4.78100
# 17               1.599000                  5.04600
# 18               1.767000                  4.64900
# 19               4.102000                  4.91400

# %%
file.isna().sum()
# Out:
# Area                       0
# Perimeter                  0
# Compactness                0
# Length of kernel           0
# Width of kernel            0
# Asymmetry coefficient      0
# Length of kernel groove    0
# dtype: int64

# %%
# done with preprocessing

# %%
#now training part

# vertical split(betw x and y)-->splitting data into features(i/p)[what should u learn to predict the o/p]
#and labels(o/p)[what u want to do]

x=file.drop("Area",axis=1)
y=file["Area"]

x
# Out:
#      Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0    14.840000     0.871000          5.763000         3.312000
# 1    14.570000     0.881100          5.630097         3.333000
# 2    14.090000     0.905000          5.291000         3.337000
# 3    13.940000     0.895500          5.324000         3.260231
# 4    14.550918     0.903400          5.658000         3.562000
# ..         ...          ...               ...              ...
# 205  13.200000     0.878300          5.137000         2.981000
# 206  12.880000     0.870873          5.140000         3.260231
# 207  13.660000     0.888300          5.236000         3.232000
# 208  13.210000     0.852100          5.630097         2.836000
# 209  14.550918     0.868400          5.243000         2.974000
#
#      Asymmetry coefficient  Length of kernel groove
# 0                 2.221000                  5.22000
# 1                 1.018000                  4.95600
# 2                 2.699000                  4.82500
# 3                 2.259000                  4.80500
# 4                 3.712436                  5.17500
# ..                     ...                      ...
# 205               3.631000                  4.87000
# 206               4.325000                  5.00300
# 207               8.315000                  5.40595
# 208               3.598000                  5.04400
# 209               5.637000                  5.06300
#
# [210 rows x 6 columns]

# %%
y
# Out:
# 0      15.260000
# 1      14.880000
# 2      14.290000
# 3      13.840000
# 4      14.888454
#          ...
# 205    12.190000
# 206    11.230000
# 207    13.200000
# 208    11.840000
# 209    12.300000
# Name: Area, Length: 210, dtype: float64

# %%
#horizontal split done using sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      Perimeter  Compactness  Length of kernel  Width of kernel  \
# 34       14.68     0.877900             5.712         3.328000
# 73       16.26     0.908100             6.154         3.930000
# 5        14.21     0.895100             5.386         3.312000
# 97       16.57     0.868700             6.449         3.552000
# 124      14.89     0.906400             5.363         3.582000
# ..         ...          ...               ...              ...
# 121      16.12     0.877200             6.059         3.563000
# 52       14.61     0.870873             5.715         3.113000
# 161      13.33     0.850300             5.350         2.810000
# 62       13.19     0.892300             5.076         3.260231
# 177      12.73     0.832900             5.145         2.642000
#
#      Asymmetry coefficient  Length of kernel groove
# 34                   2.129                  5.36000
# 73                   2.936                  6.07900
# 5                    2.462                  4.95600
# 97                   2.144                  6.45300
# 124                  3.336                  5.14400
# ..                     ...                      ...
# 121                  3.619                  6.01100
# 52                   4.116                  5.40595
# 161                  4.271                  5.30800
# 62                   3.220                  4.60500
# 177                  4.702                  4.96300
#
# [168 rows x 6 columns]

# %%
x_test
# Out:
#      Perimeter  Compactness  Length of kernel  Width of kernel  \
# 173  13.080000       0.8375          5.136000         2.763000
# 148  13.710000       0.8491          5.386000         2.911000
# 18   14.210000       0.9153          5.205000         3.466000
# 189  12.410000       0.8648          4.899000         2.787000
# 11   14.160000       0.8796          5.438000         3.201000
# 110  14.550918       0.8921          6.107000         3.769000
# 36   15.270000       0.8734          5.826000         3.464000
# 88   17.210000       0.8989          6.573000         4.033000
# 38   14.520000       0.8823          5.656000         3.288000
# 59   13.470000       0.8392          5.159000         3.032000
# 57   14.430000       0.9006          5.630097         3.412000
# 23   13.230000       0.8664          5.099000         2.936000
# 60   14.550918       0.8683          5.008000         2.850000
# 163  13.570000       0.8558          5.333000         2.968000
# 93   16.050000       0.9066          6.037000         3.860000
# 77   17.230000       0.8763          6.579000         3.814000
# 201  14.550918       0.8977          4.984000         3.135000
# 71   15.670000       0.8623          5.630097         3.484000
# 134  14.890000       0.8823          5.776000         3.408000
# 67   14.290000       0.8625          5.609000         3.158000
# 135  14.660000       0.8990          5.477000         3.465000
# 28   14.180000       0.8820          5.541000         3.221000
# 84   14.550918       0.8780          6.366000         3.260231
# 145  13.130000       0.8167          5.279000         2.687000
# 130  15.890000       0.9108          5.979000         3.755000
# 94   16.520000       0.8452          6.666000         3.485000
# 123  15.970000       0.9077          5.980000         3.771000
# 179  13.470000       0.8453          5.357000         2.893000
# 104  16.420000       0.8829          6.248000         3.755000
# 35   15.000000       0.9000          5.709000         3.485000
# 128  17.030000       0.8735          6.513000         3.773000
# 182  13.360000       0.8579          5.240000         2.909000
# 109  16.220000       0.8865          6.153000         3.674000
# 136  15.760000       0.8785          6.145000         3.574000
# 74   15.510000       0.8786          6.017000         3.486000
# 127  15.850000       0.8993          5.979000         3.687000
# 29   14.020000       0.8604          5.516000         3.065000
# 149  12.930000       0.8107          5.317000         2.648000
# 49   14.670000       0.8676          5.678000         3.258000
# 203  13.410000       0.8874          5.183000         3.091000
# 54   14.600000       0.8557          5.741000         3.260231
# 150  13.230000       0.8496          5.263000         2.840000
#
#      Asymmetry coefficient  Length of kernel groove
# 173               5.588000                    5.089
# 148               3.260000                    5.316
# 18                1.767000                    4.649
# 189               4.975000                    4.794
# 11                1.717000                    5.001
# 110               2.235000                    5.794
# 36                2.823000                    5.527
# 88                5.780000                    6.231
# 38                3.112000                    5.309
# 59                1.502000                    4.519
# 57                1.142000                    5.088
# 23                1.415000                    4.961
# 60                2.700000                    4.607
# 163               4.419000                    5.176
# 93                6.001000                    5.877
# 77                4.451000                    6.451
# 201               2.300000                    4.745
# 71                4.675000                    5.877
# 134               4.972000                    5.847
# 67                2.217000                    5.132
# 135               3.600000                    5.439
# 28                2.754000                    5.038
# 84                2.962000                    6.185
# 145               6.169000                    5.275
# 130               3.712436                    5.962
# 94                3.712436                    6.448
# 123               2.984000                    5.905
# 179               1.661000                    5.178
# 104               3.368000                    6.148
# 35                2.270000                    5.443
# 128               1.910000                    6.185
# 182               4.857000                    5.158
# 109               1.738000                    5.894
# 136               3.526000                    5.971
# 74                4.004000                    5.841
# 127               2.257000                    5.919
# 29                3.531000                    5.097
# 149               5.462000                    5.194
# 49                2.129000                    5.351
# 203               8.456000                    5.000
# 54                1.481000                    5.487
# 150               5.195000                    5.307

# %%
y_train
# Out:
# 34     15.05
# 73     19.11
# 5      14.38
# 97     18.98
# 124    15.99
#        ...
# 121    18.14
# 52     14.49
# 161    12.02
# 62     12.36
# 177    10.74
# Name: Area, Length: 168, dtype: float64

# %%
y_test
# Out:
# 173    14.888454
# 148    12.700000
# 18     14.700000
# 189    10.590000
# 11     14.030000
# 110    14.888454
# 36     16.200000
# 88     21.180000
# 38     14.800000
# 59     12.110000
# 57     14.920000
# 23     12.080000
# 60     11.420000
# 163    12.550000
# 93     18.590000
# 77     20.710000
# 201    12.670000
# 71     16.840000
# 134    15.560000
# 67     14.010000
# 135    15.380000
# 28     14.110000
# 84     19.510000
# 145    11.210000
# 130    18.300000
# 94     18.360000
# 123    18.430000
# 179    12.210000
# 104    18.950000
# 35     16.120000
# 128    20.160000
# 182    14.888454
# 109    18.550000
# 136    17.360000
# 74     16.820000
# 127    17.980000
# 29     13.450000
# 149    10.790000
# 49     14.860000
# 203    14.888454
# 54     14.520000
# 150    11.830000
# Name: Area, dtype: float64

# %%
#training the model on training data
from sklearn.ensemble import RandomForestRegressor #-->just for creating model not part of training
model=RandomForestRegressor()# for model creating

# %%
#linear reg
from sklearn import linear_model
model.fit(x_train,y_train)#-->model.fit : training model on training data of x and y
model.score(x_test,y_test)#-->model.score : testing model on training data of x and y
# Out:
# 0.7965994064182702

# %%
#naive bayes --> classification
from sklearn import naive_bayes
model.fit(x_train,y_train)#-->model.fit : training model on training data of x and y
model.score(x_test,y_test)#-->model.score : testing model on training data of x and y
# Out:
# 0.8033787975692283

# %%
#svm --> classification
from sklearn import svm
model.fit(x_train,y_train)#-->model.fit : training model on training data of x and y
model.score(x_test,y_test)#-->model.score : testing model on training data of x and y
# Out:
# 0.7949678422361586

# %%
#knn
from sklearn.neighbors import KNeighborsRegressor#-->unsupervised learning
model.fit(x_train,y_train)#-->model.fit : training model on training data of x and y
model.score(x_test,y_test)#-->model.score : testing model on training data of x and y
# Out:
# 0.8120924055859982
